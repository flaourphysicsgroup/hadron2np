# %% [markdown]
# ## 1. 导入包与查看对外暴露属性

# %%
import hadron2np

# %%
hadron2np.all_decay_processes
# Out:
# ['Lambdab->Lambda+phi',
#  'Lambdab->Lambda+phiphi',
#  'Lambdab->Lambda+X',
#  'Lambdab->Lambda+XX',
#  'Lambdab->Lambda+chichi']

# %%
hadron2np.todo_decay_processes()

# %% [markdown]
# ## 2. 生成一个衰变过程对象，并查看其属性

# %%
lb2lphi = hadron2np.new_decay_process(['Lambdab', 'Lambda', 'phi'])

# %%
lb2lphi.wcs

# %%
lb2lphi.width(wcs={}, m_dm=[1, 1])

# %% [markdown]
# ## 其它无关语句

# %%
from particle import Particle
meson = Particle.from_pdgid(5122)

# %%
meson.lifetime

# %%
print(meson.describe())

# %%
hbar = 6.582119569e-22
tau = 1.471e-12

width = 1/tau * hbar

# %%
width * 1e-3

# %%
meson.width
